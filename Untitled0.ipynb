# %% [markdown]
# <a href="https://colab.research.google.com/github/ibarrajulian263-png/laboratorio-8/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola julian")
# Out:
# Hola julian

# %%
import random

def generar_numero():
    """Genera un número aleatorio entre 1 y 100."""
    return random.randint(1, 100)

numero_secreto = generar_numero()
intentos = 0

print("¡Bienvenido al juego de adivinar el número!")
print("Estoy pensando en un número entre 1 y 100.")

while True:
    try:
        suposicion = int(input("Adivina el número: "))
        intentos += 1

        if suposicion < numero_secreto:
            print("¡Demasiado bajo! Intenta de nuevo.")
        elif suposicion > numero_secreto:
            print("¡Demasiado alto! Intenta de nuevo.")
        else:
            print(f"¡Felicidades! Adivinaste el número {numero_secreto} en {intentos} intentos.")
            break
    except ValueError:
        print("Eso no es un número válido. Por favor, ingresa un número entero.")
# Out:
# ¡Bienvenido al juego de adivinar el número!
# Estoy pensando en un número entre 1 y 100.
# Adivina el número: 10
# ¡Demasiado bajo! Intenta de nuevo.
# Adivina el número: 20
# ¡Demasiado alto! Intenta de nuevo.
# Adivina el número: 0
# ¡Demasiado bajo! Intenta de nuevo.
# Adivina el número: 2
# ¡Demasiado bajo! Intenta de nuevo.
# Adivina el número: 5
# ¡Demasiado bajo! Intenta de nuevo.
# Adivina el número: 8
# ¡Demasiado bajo! Intenta de nuevo.
# Adivina el número: 9
# ¡Demasiado bajo! Intenta de nuevo.
# Adivina el número: 11
# ¡Felicidades! Adivinaste el número 11 en 8 intentos.
